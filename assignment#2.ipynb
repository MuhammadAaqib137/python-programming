# %%
for i in range(6):
    name = input("Enter the name of student:")
    if name == 'aamir' or name =='AAMIR' or name == 'Aamir':
        print("Enter marks of Aamir:")
        english = float(input("English:"))
        maths = float(input("Maths:"))
        physics = float(input("Physics:"))
        total = 300
        marks_gained = english + maths + physics
        percentage = float((marks_gained/total)*100)
        
        grade = None
        
        if percentage >= 80:
            grade = print("A1 Grade")
        elif percentage >= 70:
            grade = print("A Grade")
        elif percentage >= 60:
            grade = print("B Grade")
        elif percentage >=50:
            grade = print("C Grade")
        else:
            grade = print("Fail")
            
        
        print("Aamir'S MARKSHEET:\n","English:\n",english,"\n Maths: \n",maths,"\n Physics: \n",physics,"\n Marks_Obtained: \n",marks_gained,"\n Percentage: \n",percentage,"%","\n Grade: \n",grade) 
        
    elif name == 'amrit' or name == 'AMRIT' or name == 'Amrit':
        print("Enter marks of amrit:")
        english = float(input("English:"))
        maths = float(input("Maths:"))
        physics = float(input("Physics:"))
        total = 300
        marks_gained = english + maths + physics
        percentage = float((marks_gained/total)*100)
        
        grade = None
        
        if percentage >= 80:
            grade = print("A1 Grade")
        elif percentage >= 70:
            grade = print("A Grade")
        elif percentage >= 60:
            grade = print("B Grade")
        elif percentage >=50:
            grade = print("C Grade")
        else:
            grade = print("Fail")
        
        print("AMRIT'S MARKSHEET:\n","English:\n",english,"\n Maths: \n",maths,"\n Physics: \n",physics,"\n Marks_Obtained: \n",marks_gained,"\n Percentage: \n",percentage,"%","\n Grade: \n",grade) 
        
    elif name == 'aaqib' or name == 'AAQIB' or name == 'Aaqib':
        print("Enter marks of Aaqib:")
        english = float(input("English:"))
        maths = float(input("Maths:"))
        physics = float(input("Physics:"))
        total = 300
        marks_gained = english + maths + physics
        percentage = float((marks_gained/total)*100)
        
        grade = None
        
        if percentage >= 80:
            grade = print("A1 Grade")
        elif percentage >= 70:
            grade = print("A Grade")
        elif percentage >= 60:
            grade = print("B Grade")
        elif percentage >=50:
            grade = print("C Grade")
        else:
            grade = print("Fail")
        
        print("Aaqib'S MARKSHEET:\n","English:\n",english,"\n Maths: \n",maths,"\n Physics: \n",physics,"\n Marks_Obtained: \n",marks_gained,"\n Percentage: \n",percentage,"%","\n Grade: \n",grade)    
        
    else:
        print("Invalid name")
# Out:
# Enter the name of student:aaqib
# Enter marks of Aaqib:
# English:80
# Maths:92
# Physics:91
# A1 Grade
# Aaqib'S MARKSHEET:
#  English:
#  80.0
#  Maths:
#  92.0
#  Physics:
#  91.0
#  Marks_Obtained:
#  263.0
#  Percentage:
#  87.66666666666667 %
#  Grade:
#  None
